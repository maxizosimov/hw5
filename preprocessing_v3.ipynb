# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spotify.csv')

# pre-look into the data to determine properties of similarity (to define similarity)
df.head()

# are there duplicated track_id / track_name we have to handle?
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
print(df.columns)
pre_df = df.copy()
pre_df = pre_df.drop(['Unnamed: 0', 'duration_ms', 'explicit', 'time_signature', 'key'], axis=1)

pre_df.head(20)
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')
#                   track_id                               artists  \
# 0   5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1   4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2   1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3   6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4   5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5   01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6   6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7   1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8   0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9   7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# 11  5ivF4eQBqJiVL5IAE9jRyl                            Jason Mraz
# 12  4ptDJbJl35d7gQfeNteBwp                              Dan Berk
# 13  0X9MxHR1rTkEHDjp95F2OO                         Anna Hamilton
# 14  4LbWtBkN82ZRhz9jqzgrb3              Chord Overstreet;Deepend
# 15  1KHdq8NK9QxnGjdXb55NiG                           Landon Pigg
# 16  6xKeQgzfjixSUld14qUezm                  Andrew Foy;Renee Foy
# 17  4Yo0igmcoNyat1secaH0OD                  Andrew Foy;Renee Foy
# 18  2qLMf6TuEC3ruGJg4SMMN6             Jason Mraz;Colbie Caillat
# 19  6CgNoAbFJ4Q4Id4EjtbXlC               Boyce Avenue;Bea Miller
#
#                                            album_name  \
# 0                                              Comedy
# 1                                    Ghost (Acoustic)
# 2                                      To Begin Again
# 3   Crazy Rich Asians (Original Motion Picture Sou...
# 4                                             Hold On
# 5                                Days I Will Remember
# 6                         Is There Anybody Out There?
# 7                 We Sing. We Dance. We Steal Things.
# 8                 We Sing. We Dance. We Steal Things.
# 9                                              Hunger
# 10                                            Episode
# 11                         Love Is a Four Letter Word
# 12                                               Solo
# 13                                           Bad Liar
# 14                                    Hold On (Remix)
# 15                                  The Boy Who Never
# 16                              ily (i love you baby)
# 17                                        At My Worst
# 18                We Sing. We Dance. We Steal Things.
# 19                             Cover Sessions, Vol. 4
#
#                           track_name  popularity  danceability  energy  \
# 0                             Comedy          73         0.676  0.4610
# 1                   Ghost - Acoustic          55         0.420  0.1660
# 2                     To Begin Again          57         0.438  0.3590
# 3         Can't Help Falling In Love          71         0.266  0.0596
# 4                            Hold On          82         0.618  0.4430
# 5               Days I Will Remember          58         0.688  0.4810
# 6                      Say Something          74         0.407  0.1470
# 7                          I'm Yours          80         0.703  0.4440
# 8                              Lucky          74         0.625  0.4140
# 9                             Hunger          56         0.442  0.6320
# 10              Give Me Your Forever          74         0.627  0.3630
# 11                   I Won't Give Up          69         0.483  0.3030
# 12                              Solo          52         0.489  0.3140
# 13                          Bad Liar          62         0.691  0.2340
# 14                   Hold On - Remix          56         0.755  0.7800
# 15  Falling in Love at a Coffee Shop          58         0.489  0.5610
# 16             ily (i love you baby)          56         0.706  0.1120
# 17                       At My Worst          54         0.795  0.0841
# 18                             Lucky          68         0.625  0.4140
# 19                        Photograph          67         0.717  0.3200
#
#     loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0     -6.746     0       0.1430        0.0322          0.000001    0.3580
# 1    -17.235     1       0.0763        0.9240          0.000006    0.1010
# 2     -9.734     1       0.0557        0.2100          0.000000    0.1170
# 3    -18.515     1       0.0363        0.9050          0.000071    0.1320
# 4     -9.681     1       0.0526        0.4690          0.000000    0.0829
# 5     -8.807     1       0.1050        0.2890          0.000000    0.1890
# 6     -8.822     1       0.0355        0.8570          0.000003    0.0913
# 7     -9.331     1       0.0417        0.5590          0.000000    0.0973
# 8     -8.700     1       0.0369        0.2940          0.000000    0.1510
# 9     -6.770     1       0.0295        0.4260          0.004190    0.0735
# 10    -8.127     1       0.0291        0.2790          0.000000    0.0928
# 11   -10.058     1       0.0429        0.6940          0.000000    0.1150
# 12    -9.245     0       0.0331        0.7490          0.000000    0.1130
# 13    -6.441     1       0.0285        0.7770          0.000000    0.1200
# 14    -6.084     1       0.0327        0.1240          0.000028    0.1210
# 15    -7.933     1       0.0274        0.2000          0.000046    0.1790
# 16   -18.098     1       0.0391        0.8270          0.000004    0.1250
# 17   -18.090     0       0.0461        0.7420          0.000012    0.0853
# 18    -8.700     1       0.0369        0.2940          0.000000    0.1510
# 19    -8.393     1       0.0283        0.8300          0.000000    0.1070
#
#     valence    tempo track_genre
# 0    0.7150   87.917    acoustic
# 1    0.2670   77.489    acoustic
# 2    0.1200   76.332    acoustic
# 3    0.1430  181.740    acoustic
# 4    0.1670  119.949    acoustic
# 5    0.6660   98.017    acoustic
# 6    0.0765  141.284    acoustic
# 7    0.7120  150.960    acoustic
# 8    0.6690  130.088    acoustic
# 9    0.1960   78.899    acoustic
# 10   0.3010   99.905    acoustic
# 11   0.1390  133.406    acoustic
# 12   0.6070  124.234    acoustic
# 13   0.2090   87.103    acoustic
# 14   0.3870  120.004    acoustic
# 15   0.2380   83.457    acoustic
# 16   0.4140  110.154    acoustic
# 17   0.6090   91.803    acoustic
# 18   0.6690  130.088    acoustic
# 19   0.3220  107.946    acoustic

# %%
# pre_proc df ideas
# Filter out any songs by The Strokes except those from the "Is This It" album 
# danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, genre and tempo
# Normalize the data
# Sampling

# %%
# Normalize the data
from sklearn.preprocessing import MinMaxScaler

# features that might influence song similarity - no need for mode (binary) and genre (categorical)
continuous_features = ['popularity', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 
                       'instrumentalness', 'liveness', 'valence', 'tempo']

# normalizing these features
scaler = MinMaxScaler()
pre_df[continuous_features] = scaler.fit_transform(pre_df[continuous_features])

pre_df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  danceability  energy  loudness  \
# 0                      Comedy        0.73      0.686294  0.4610  0.791392
# 1            Ghost - Acoustic        0.55      0.426396  0.1660  0.597377
# 2              To Begin Again        0.57      0.444670  0.3590  0.736123
# 3  Can't Help Falling In Love        0.71      0.270051  0.0596  0.573701
# 4                     Hold On        0.82      0.627411  0.4430  0.737103
#
#    mode  speechiness  acousticness  instrumentalness  liveness   valence  \
# 0     0     0.148187      0.032329          0.000001    0.3580  0.718593
# 1     1     0.079067      0.927711          0.000006    0.1010  0.268342
# 2     1     0.057720      0.210843          0.000000    0.1170  0.120603
# 3     1     0.037617      0.908635          0.000071    0.1320  0.143719
# 4     1     0.054508      0.470884          0.000000    0.0829  0.167839
#
#       tempo track_genre
# 0  0.361245    acoustic
# 1  0.318397    acoustic
# 2  0.313643    acoustic
# 3  0.746758    acoustic
# 4  0.492863    acoustic

# %%
the_strokes_album_songs = pre_df[(pre_df['artists'].str.contains("The Strokes")) & (pre_df['album_name'] == "Is This It")]

sampling_pool = pre_df[~((pre_df['artists'].str.contains("The Strokes")) & (pre_df['album_name'] == "Is This It"))]

# Sample other songs
sampled_songs = sampling_pool.sample(n=30000)

final_sampled_df = pd.concat([the_strokes_album_songs, sampled_songs])

final_sampled_df.head()
# Out:
#                      track_id      artists  album_name       track_name  \
# 2709   7kzKAuUzOITUauHAhoMoxA  The Strokes  Is This It        Last Nite
# 38073  56NkIxSZZiMpFP5ZNSxtnT  The Strokes  Is This It          Someday
# 38074  7kzKAuUzOITUauHAhoMoxA  The Strokes  Is This It        Last Nite
# 38114  2pAD0PKMUMtxlMvz33tYzB  The Strokes  Is This It       Is This It
# 38181  2LMloFiV7DHpBhITOaBSam  The Strokes  Is This It  Hard To Explain
#
#        popularity  danceability  energy  loudness  mode  speechiness  \
# 2709         0.74      0.633503   0.910  0.810684     1     0.030777
# 38073        0.70      0.550254   0.531  0.777796     1     0.031192
# 38074        0.74      0.633503   0.910  0.810684     1     0.030777
# 38114        0.61      0.674112   0.679  0.762777     1     0.031088
# 38181        0.63      0.412183   0.682  0.799993     1     0.060518
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 2709       0.028614          0.000198    0.0789  0.770854  0.427502
# 38073      0.003313          0.000002    0.3380  0.674372  0.435424
# 38074      0.028614          0.000198    0.0789  0.770854  0.427502
# 38114      0.149598          0.000048    0.3470  0.808040  0.394466
# 38181      0.000415          0.849000    0.0999  0.626131  0.338967
#
#       track_genre
# 2709     alt-rock
# 38073      garage
# 38074      garage
# 38114      garage
# 38181      garage

# %%
# sampling, normalizing and filtering done

final_sampled_df.to_csv('experimental_euclidian_spotify.csv')

# %%
from sklearn.metrics import pairwise_distances

# similarity measure to create a csv for relationships

# loading normalized dataset
df_norm = pd.read_csv('experimental_euclidian_spotify.csv')

# selecting features that I think is important for song similarity - Popularity (not recommend just feature close)?
features = ['popularity', 'danceability', 'energy', 'loudness', 'mode', 'speechiness', 
            'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# convering to np array
X = df_norm[features].values

# getting pairwise euclidean distances
distance_matrix = pairwise_distances(X, metric='euclidean')

# to include id information alongside distances (track id in case of identical (duplicate) song names)
song_ids = df_norm['track_id'].tolist()
distances_long_df = pd.DataFrame([(song_ids[i], song_ids[j], distance_matrix[i, j]) 
                                  for i in range(len(song_ids)) 
                                  for j in range(i + 1, len(song_ids))], 
                                 columns=['SongID1', 'SongID2', 'Distance'])

# %%
# Export to CSV
distances_long_df.to_csv('experimental_euclidian_relationships.csv', index=False)

# %%
distances_long_df.head()
# Out:
#                   SongID1                 SongID2  Distance
# 0  7kzKAuUzOITUauHAhoMoxA  56NkIxSZZiMpFP5ZNSxtnT  0.479998
# 1  7kzKAuUzOITUauHAhoMoxA  7kzKAuUzOITUauHAhoMoxA  0.000000
# 2  7kzKAuUzOITUauHAhoMoxA  2pAD0PKMUMtxlMvz33tYzB  0.403973
# 3  7kzKAuUzOITUauHAhoMoxA  2LMloFiV7DHpBhITOaBSam  0.929812
# 4  7kzKAuUzOITUauHAhoMoxA  4KC2Z9dL4jL61Ys35N6srg  0.360336

# %%
import matplotlib.pyplot as plt
# plotting the distribution of distances to decide threshold
plt.figure(figsize=(10, 6))
plt.hist(distances_long_df['Distance'], bins=50, alpha=0.7, color='blue')
plt.title('Distribution of Song Distances')
plt.xlabel('Euclidean Distance')
plt.ylabel('Frequency')
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
# basic stats to help determine threshold
distances_long_df['Distance'].describe()
# Out:
# count    4.503451e+08
# mean     1.144060e+00
# std      3.668265e-01
# min      0.000000e+00
# 25%      8.776538e-01
# 50%      1.176990e+00
# 75%      1.396992e+00
# max      2.569987e+00
# Name: Distance, dtype: float64

# %%
song = pre_df[pre_df['track_name'] == 'One Way Or Another - Remastered/2001'] 
# 3NRVfxtC8mYrPoHjKahcng - dispara | 2kk8L2MStsZ0tYLPkDrL64 - 地球号 | 5YqdiryRmdAzYFlxo43hAJ - Missing Piece
# 1Uu1dI6OcKWuMLLv8ki3lN - All Star
iti = pre_df[pre_df['album_name'] == 'Is This It']

#song.head()
iti
# Out:
#                      track_id      artists  album_name           track_name  \
# 2709   7kzKAuUzOITUauHAhoMoxA  The Strokes  Is This It            Last Nite
# 38073  56NkIxSZZiMpFP5ZNSxtnT  The Strokes  Is This It              Someday
# 38074  7kzKAuUzOITUauHAhoMoxA  The Strokes  Is This It            Last Nite
# 38114  2pAD0PKMUMtxlMvz33tYzB  The Strokes  Is This It           Is This It
# 38181  2LMloFiV7DHpBhITOaBSam  The Strokes  Is This It      Hard To Explain
# 38225  4KC2Z9dL4jL61Ys35N6srg  The Strokes  Is This It         Barely Legal
# 38232  1EsgUWQsxGBwnu3NATDjiU  The Strokes  Is This It       The Modern Age
# 38357  7G8hUONVhvJnkD3Ak8mNF1  The Strokes  Is This It                 Soma
# 38459  4pXyK9GW7fuT645U0DLYYF  The Strokes  Is This It      Alone, Together
# 38512  37cb7mzkQKksGm0noGDXeh  The Strokes  Is This It     Trying Your Luck
# 38618  0J2OnBNKwt0KICDyDFPUvl  The Strokes  Is This It  Take It Or Leave It
# 38675  7xuu4ByQkm8qhnwJQk994r  The Strokes  Is This It   New York City Cops
#
#        popularity  danceability  energy  loudness  mode  speechiness  \
# 2709         0.74      0.633503   0.910  0.810684     1     0.030777
# 38073        0.70      0.550254   0.531  0.777796     1     0.031192
# 38074        0.74      0.633503   0.910  0.810684     1     0.030777
# 38114        0.61      0.674112   0.679  0.762777     1     0.031088
# 38181        0.63      0.412183   0.682  0.799993     1     0.060518
# 38225        0.57      0.433503   0.886  0.799567     1     0.038342
# 38232        0.57      0.538071   0.890  0.804413     1     0.033990
# 38357        0.54      0.508629   0.715  0.779627     1     0.031192
# 38459        0.52      0.518782   0.855  0.809777     1     0.031813
# 38512        0.53      0.509645   0.691  0.741320     0     0.032228
# 38618        0.53      0.435533   0.924  0.802767     0     0.042073
# 38675        0.52      0.529949   0.853  0.774485     1     0.037513
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 2709       0.028614          0.000198    0.0789  0.770854  0.427502
# 38073      0.003313          0.000002    0.3380  0.674372  0.435424
# 38074      0.028614          0.000198    0.0789  0.770854  0.427502
# 38114      0.149598          0.000048    0.3470  0.808040  0.394466
# 38181      0.000415          0.849000    0.0999  0.626131  0.338967
# 38225      0.004016          0.053200    0.0909  0.861307  0.647605
# 38232      0.012450          0.759000    0.1430  0.872362  0.599732
# 38357      0.077711          0.006030    0.0653  0.504523  0.612112
# 38459      0.007851          0.890000    0.0694  0.966834  0.587516
# 38512      0.009147          0.014900    0.1330  0.632161  0.591383
# 38618      0.000544          0.353000    0.1040  0.486432  0.633203
# 38675      0.071285          0.000028    0.3430  0.457286  0.443531
#
#       track_genre
# 2709     alt-rock
# 38073      garage
# 38074      garage
# 38114      garage
# 38181      garage
# 38225      garage
# 38232      garage
# 38357      garage
# 38459      garage
# 38512      garage
# 38618      garage
# 38675      garage

# %%
# List of track_ids from the "Is This It" album
is_this_it_track_ids = ['7kzKAuUzOITUauHAhoMoxA', '56NkIxSZZiMpFP5ZNSxtnT', '7kzKAuUzOITUauHAhoMoxA', '2pAD0PKMUMtxlMvz33tYzB', 
                        '2LMloFiV7DHpBhITOaBSam', '4KC2Z9dL4jL61Ys35N6srg', '1EsgUWQsxGBwnu3NATDjiU', '7G8hUONVhvJnkD3Ak8mNF1', '4pXyK9GW7fuT645U0DLYYF', 
                        '37cb7mzkQKksGm0noGDXeh', '0J2OnBNKwt0KICDyDFPUvl', '7xuu4ByQkm8qhnwJQk994r']

# Filter the DataFrame for rows where '3NRVfxtC8mYrPoHjKahcng' is in either SongID1 or SongID2
filtered_df = distances_long_df[(distances_long_df['SongID1'] == '4cQJ27R11K634x5qCOwKW5') | (distances_long_df['SongID2'] == '4cQJ27R11K634x5qCOwKW5')]

# Check if the corresponding SongID is in the list of 'Is This It' track_ids
matches = filtered_df[(filtered_df['SongID1'].isin(is_this_it_track_ids)) | (filtered_df['SongID2'].isin(is_this_it_track_ids))]

matches.sort_values(by='Distance', ascending=True)
# Out:
# Empty DataFrame
# Columns: [SongID1, SongID2, Distance]
# Index: []

# %%
# TO DO:
# Update threshold if needed
# Upload new preprocessed data and relationships csv (more features)
# Fix problem with song recommendations only being close to Late Nite
# Create a function to get recommendations for any song
# Include Genre aspect to song recommendation
# - when including genre aspect think about:
# euclidian distance between same songs will be 0.0000 --> 
# filter out where euclidian distance is 0 < distance <= x

# randomly sample 10k new songs / increase sample to 20k but reducing threshold to limit edges

# EXTRA:
# Create a function to get recommendations for any album

# %%
# problems 
# 1. First songs good, then jump in distance - not sure why, and why so few nodes at threshold 0.2
# 2. how to incorporate genre into the recommendation system
